# %%
from __future__ import print_function, division
from future.utils import iteritems
from builtins import range

# %%
from gensim.models import KeyedVectors

# %%
word_vectors = KeyedVectors.load_word2vec_format('large_files/GoogleNews-vectors-negative300.bin', binary=True)

# %%
def find_analogies(w1, w2, w3):
    r = word_vectors.most_similar(positive=[w1, w3], negative=[2])
    print("%s - %s = %s - %s" % (w1, w2, r[0][0], w3))

# %%
def nearest_neighbors(w):
    r = word_vectors.most_similar(positive=[w])
    print("neighbors of: %s" % w)
    for word, score in r:
        print("\t%s" % word)

# %%
find_analogies('king', 'man', 'woman')
find_analogies('france', 'paris', 'london')
find_analogies('japan', 'japanese', 'chinese')
find_analogies('japan', 'japanese', 'italian')
find_analogies('japan', 'japanese', 'australian')
find_analogies('december', 'november', 'june')
find_analogies('man', 'woman', 'shee')
find_analogies('man', 'woman', 'aunt')
find_analogies('man', 'woman', 'sister')
find_analogies('man', 'woman', 'wife')
find_analogies('man', 'woman', 'child')
find_analogies('man', 'woman', 'mother')
find_analogies('heir', 'heiress', 'princess')
find_analogies('france', 'paris', 'japan')
find_analogies('france', 'paris', 'rome')
find_analogies('france', 'paris', 'italy')
find_analogies('france', 'paris', 'beijing')
find_analogies('miami', 'florida', 'texas')

nearest_neighbors('king')
nearest_neighbors('france')
nearest_neighbors('japan')
nearest_neighbors('november')
nearest_neighbors('woman')
nearest_neighbors('nephew')
nearest_neighbors('february')
nearest_neighbors('rome')
# Out:
# king - man = queen - woman
# france - paris = england - london
# japan - japanese = japanese - chinese
# japan - japanese = japanese - italian
# japan - japanese = japanese - australian
# december - november = september - june
# man - woman = FRAY' - shee
# man - woman = grandmother - aunt
# man - woman = mother - sister
# man - woman = woman - wife
# man - woman = boy - child
# man - woman = woman - mother
# heir - heiress = prince - princess
# france - paris = germany - japan
# france - paris = spain - rome
# france - paris = spain - italy
# france - paris = 谷 - beijing
# miami - florida = florida - texas
# neighbors of: king
# 	kings
# 	queen
# 	monarch
# 	crown_prince
# 	prince
# 	sultan
# 	ruler
# 	princes
# 	Prince_Paras
# 	throne
# neighbors of: france
# 	spain
# 	french
# 	germany
# 	europe
# 	italy
# 	england
# 	european
# 	belgium
# 	usa
# 	serbia
# neighbors of: japan
# 	japanese
# 	tokyo
# 	america
# 	europe
# 	germany
# 	chinese
# 	india
# 	hawaii
# 	usa
# 	korea
# ...
